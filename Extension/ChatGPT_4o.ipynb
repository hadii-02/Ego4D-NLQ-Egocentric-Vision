# %% [markdown]
# <a href="https://colab.research.google.com/github/arianmo477/EgoCentricVisionPolito/blob/main/Extension/ChatGPT_4o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##General Setup
#
# Imports and persistant storage in google drive.

# %%
# !pip install av
# Out:
# Requirement already satisfied: av in /usr/local/lib/python3.11/dist-packages (14.4.0)

# %%
# --- standard library ---
import os
import gc
import json
from pathlib import Path
from io import BytesIO
import base64

# --- third-party ---
import numpy as np
import pandas as pd
from tqdm import tqdm
import av
import torch
from PIL import Image
import google.generativeai as genai
from google.api_core.exceptions import ResourceExhausted, BadRequest, InternalServerError

# --- Colab-specific ---
from google.colab import drive, userdata

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
CUT_VIDEO_OUT = "/content/drive/MyDrive/model_2.0/model/cut_videos_6tol"

# %%
annotations_path = f'/content/drive/MyDrive/model_2.0/model/GroundTruth.xlsx'
annotations_df = pd.read_excel(annotations_path)

annotations_df.head()
# Out:
#    idx                        annotation_uid  \
# 0    0  93891b44-c00f-43d9-885b-92fdce39128c
# 1    1  00bb3571-8b35-40ba-8163-a1a0fd20b886
# 2    2  d8fb0c3d-39b1-4bb2-b800-fc56f12ab120
# 3    3  e8b1352a-6e0c-4f86-8a52-afe93743abb6
# 4    4  2bc5aa4c-3114-497e-9d13-e229277fe11b
#
#                                clip_uid  \
# 0  75d3fc52-3776-47d4-b7fd-8074d30b06d1
# 1  60e7e14d-cbed-46d1-924d-6ce451ea7d7c
# 2  e1c79556-e8af-4e26-bc4c-633100277239
# 3  efc190a8-45de-4ce5-b480-b722403bcec1
# 4  cc6270fd-3c0d-4dda-bcb4-52cefc0224d7
#
#                                         sentence predicted_times  \
# 0                Where did I put the chopsticks.     (0.0, 3.75)
# 1                       What cable did I remove?  (78.75, 86.25)
# 2                  Did I close the refrigerator?     (0.0, 3.75)
# 3  Where was the scissors before I picked it up?   (93.75, 97.5)
# 4          In what location did I open the door?     (3.75, 7.5)
#
#             exact_times                             video_uid  \
# 0        (3.319, 4.619)  413fe086-1745-4573-b75b-e7d26ff72df9
# 1  (84.32902, 84.71152)  03e90bbc-7d6b-423c-84d9-b5be3eff11c5
# 2    (0.65536, 2.00097)  4ce119de-0f42-4bd1-b387-9e19643fdddc
# 3        (87.0, 89.306)  ff6d3d52-dda5-46dd-8515-b9b772933030
# 4       (6.2829, 8.428)  432cb803-6be5-47bc-8443-6bb5b9051667
#
#         ground truth
# 0   beside the stove
# 1          usb drive
# 2                yes
# 3  on the plate rack
# 4    in the bathroom

# %% [markdown]
# Define model.

# %%
from openai import OpenAI

# ✅ Set and configure OpenAI API key
client = OpenAI(api_key=userdata.get("OPENAI_API_KEY"))  # ← Replace with secure key

# GPT-4o is accessed dynamically through Chat API; no need to "load a model"
# You’ll use it inside ChatCompletion like:
# model="gpt-4o" in your completion call

# %% [markdown]
# Define model usage functions.

# %%
import re

def build_general_prompt(sentence: str) -> str:
    q = sentence.strip().lower()

    prompt = (
        "### SYSTEM:\n"
        "You are a helpful assistant that answers questions based on visual summaries of video segments.\n"
        "Use only the information visible in the video.\n"
        "Be accurate and respond in **5 words or fewer**.\n\n"

        "### CONTEXT:\n"
        "<video>\n"
        "(Visual summary of the video is shown here)\n\n"

        f"### USER:\nQuestion: {sentence.strip()}\n"
    )

    # -------------------------------
    # 🔍 Task Classification Logic
    # -------------------------------

    # 1. Counting tasks
    if re.search(r'\bhow many\b', q):
        prompt += (
            "\n### TASK INSTRUCTION:\n"
            "This is a counting task. Count only the visible items.\n"
            "Return the number.\n"
        )

    # 2. Color detection
    elif re.search(r'\bwhat (color|colour)\b', q):
        prompt += (
            "\n### TASK INSTRUCTION:\n"
            "Identify the visible color of the mentioned object.\n"
        )

    # 3. Location questions (debiased)
    elif re.search(r'\bwhere (is|was|did|do)\b|\bin what location\b', q):
        prompt += (
            "\n### TASK INSTRUCTION:\n"
            "Identify the object's visible spatial location based only on the video summary.\n"
            "Use only location descriptions directly inferable from the visual context.\n"
        )

    # 4. Action-object identification
    elif re.search(r'\bwhat\b', q) and re.search(
        r'\b(remove|pick|grab|cut|wash|tie|wipe|press|use|carry|put|insert|drop|place)\b', q
    ):
        prompt += (
            "\n### TASK INSTRUCTION:\n"
            "Identify the object involved in the action based on what is clearly visible in the video.\n"
        )

    # 5. Tool/machine recognition
    elif re.search(r'\bwhat\b', q) and re.search(r'\b(tool|machine|device|object|item|equipment)\b', q):
        prompt += (
            "\n### TASK INSTRUCTION:\n"
            "Determine what object, tool, or machine was used. Base your answer only on visible cues.\n"
        )

    # 6. Human interaction
    elif re.search(r'\bwho did (i|he|she|we|they) (talk|interact)\b', q):
        prompt += (
            "\n### TASK INSTRUCTION:\n"
            "Name the person involved in the interaction.\n"
        )

    # 7. Yes/no — fallback only
    elif (
        re.search(r'\bdid\b.*\b(i|we|they|he|she)\b', q)
        and not re.search(r'\bwhat\b', q)
        and not re.search(r'\bwho\b', q)
    ):
        prompt += (
            "\n### TASK INSTRUCTION:\n"
            "This is a yes/no question. Respond with 'yes' or 'no' based on visible evidence only.\n"
        )

    # 8. Fallback
    else:
        prompt += (
            "\n### TASK INSTRUCTION:\n"
            "Answer briefly and accurately using only the information visible in the video summary.\n"
        )

    prompt += "\nAnswer:\n"
    return prompt

# %% [markdown]
# Feed prompts and video into model.

# %%
def make_grid_image(frames, grid_size=(2, 4)):
    assert len(frames) == 8, "Exactly 8 frames are expected"
    frame_width, frame_height = frames[0].size
    grid_image = Image.new('RGB', (grid_size[1] * frame_width, grid_size[0] * frame_height))

    for idx, frame in enumerate(frames):
        row = idx // grid_size[1]
        col = idx % grid_size[1]
        grid_image.paste(frame, (col * frame_width, row * frame_height))
    return grid_image

def read_video_frames(container, indices):
    frames = []
    container.seek(0)
    for i, frame in enumerate(container.decode(video=0)):
        if i > indices[-1]:
            break
        if i in indices:
            frames.append(frame.to_ndarray(format='rgb24'))
    while len(frames) < 8:
        frames.append(frames[-1])
    return frames

def frame_to_pil(frame):
    return Image.fromarray(frame)


def prepare_gpt4o_inputs(row, video_segments_dir):
    clip_uid = row['clip_uid']
    annotation_uid = row['annotation_uid']
    sentence = row['sentence']
    idx = int(row['idx'])

    video_segment_path = os.path.join(video_segments_dir, f"{idx}_{clip_uid}_{annotation_uid}.mp4")
    if not os.path.exists(video_segment_path):
        print(f"⚠️ File not found: {video_segment_path}")
        return None, None

    try:
        container = av.open(video_segment_path)
        if not container.streams.video:
            print(f"⚠️ No video stream in: {video_segment_path}")
            return None, None

        total_frames = container.streams.video[0].frames
        indices = np.linspace(0, total_frames - 1, num=8, dtype=int)
        frames = read_video_frames(container, indices)
        pil_frames = [frame_to_pil(f) for f in frames]
        grid_image = make_grid_image(pil_frames)
        prompt = build_general_prompt(sentence)
        return grid_image, prompt

    except Exception as e:
        print(f"❌ Error reading video {video_segment_path}: {e}")
        return None, None


def process_row_with_gpt4o(row):
    image, prompt = prepare_gpt4o_inputs(row, CUT_VIDEO_OUT)
    if image is None:
        print(f"⚠️ Skipping idx {row['idx']}")
        return None

    try:
        buffered = BytesIO()
        image.save(buffered, format="PNG")
        img_base64 = base64.b64encode(buffered.getvalue()).decode("utf-8")

        response = client.chat.completions.create(
            model="gpt-4o",
            max_tokens=3000,

            messages=[
                {
                    "role": "user",
                    "content": [
                        {"type": "text", "text": prompt},
                        {"type": "image_url", "image_url": {"url": f"data:image/png;base64,{img_base64}"}}
                    ]
                }
            ]
        )

        answer = response.choices[0].message.content.strip()
        print(f"✅ idx {row['idx']} → {answer}")

        return {
            'idx': row['idx'],
            'annotation_uid': row['annotation_uid'],
            'clip_uid': row['clip_uid'],
            'sentence': row['sentence'],
            'predicted_times': row['predicted_times'],
            'exact_times': row['exact_times'],
            'video_uid': row['video_uid'],
            'ground truth': row['ground truth'],
            'answer': answer.split("Answer:")[-1].strip() if "Answer:" in answer else answer,
        }

    except Exception as e:
        print(f"❌ GPT-4o API error at idx {row['idx']}: {e}")
        return None

# %%
import os
import pandas as pd
import gc

# ✅ Path to save results
CHECKPOINT_PATH = "/content/drive/MyDrive/model_2.0/model/results/gpt4o_3000tokens.csv"
CHECKPOINT_EVERY = 20

answers = []

# ✅ Load checkpoint if it exists
if os.path.exists(CHECKPOINT_PATH):
    answers_df = pd.read_csv(CHECKPOINT_PATH)
    processed_keys = set(answers_df.apply(lambda row: f"{row['clip_uid']}::{row['annotation_uid']}", axis=1))
    answers = answers_df.to_dict(orient="records")
    print(f"🔁 Resuming from checkpoint: {len(answers)} examples already processed.")
else:
    answers_df = pd.DataFrame()
    processed_keys = set()
    print("🆕 No checkpoint found, starting fresh.")

# ✅ Process all rows from annotations_df
for i, row in annotations_df.iterrows():
    key = f"{row['clip_uid']}::{row['annotation_uid']}"

    if key in processed_keys:
        continue  # ✅ Skip already processed

    result = process_row_with_gpt4o(row)  # ⬅️ Replaces process_row_with_gemini

    if result:
        answers.append(result)
        processed_keys.add(key)

    # 💾 Periodic checkpoint
    if len(answers) % CHECKPOINT_EVERY == 0:
        answers_df = pd.DataFrame(answers)
        answers_df.to_csv(CHECKPOINT_PATH, index=False)
        print(f"💾 Checkpoint saved with {len(answers)} entries.")

    gc.collect()

# ✅ Final save
answers_df = pd.DataFrame(answers)
answers_df.to_csv(CHECKPOINT_PATH, index=False)
print("✅ Final save completed. Total entries:", len(answers))
# Out:
# 🆕 No checkpoint found, starting fresh.
# ✅ idx 0 → You are holding them.
# ✅ idx 1 → Black HDMI cable
# ✅ idx 2 → No.
# ✅ idx 3 → Next to the cutting board.
# ✅ idx 4 → Bathroom.
# ✅ idx 5 → Hanging on door hook.
# ✅ idx 6 → Next to workbench, center-left.
# ✅ idx 7 → Brown leather band.
# ✅ idx 9 → Zero
# ✅ idx 10 → On the kitchen counter, right.
# ✅ idx 11 → Above the red toolbox.
# ✅ idx 12 → On a wooden board.
# ✅ idx 14 → On the table, in play.
# ✅ idx 15 → In the sink, bottom-left.
# ✅ idx 16 → On the couch.
# ⚠️ No video stream in: /content/drive/MyDrive/model_2.0/model/cut_videos_6tol/17_679cfee6-7da1-4701-b75a-9e34abb9400a_e3015a5a-3e3e-47f5-a6b9-b77d3648621e.mp4
# ⚠️ Skipping idx 17
# ✅ idx 18 → Above the cutting board.
# ✅ idx 20 → In the open toolbox drawer.
# ✅ idx 22 → Inside the top kitchen cabinet.
# ✅ idx 24 → On the living room floor.
# ✅ idx 25 → Underneath stack of bowls.
# 💾 Checkpoint saved with 20 entries.
# ⚠️ No video stream in: /content/drive/MyDrive/model_2.0/model/cut_videos_6tol/26_3341648c-88b4-433a-87ac-1fcc9619a4dc_8e2fed00-ea98-4cc4-b8e7-faecffe28d90.mp4
# ⚠️ Skipping idx 26
# 💾 Checkpoint saved with 20 entries.
# ✅ idx 27 → I don't know.
# ✅ idx 28 → One
# ✅ idx 30 → I don't know.
# ✅ idx 31 → On the window ledge.
# ✅ idx 32 → On the kitchen counter.
# ✅ idx 33 → Wet/dry vacuum.
# ✅ idx 35 → Outside on a small terrace.
# ✅ idx 36 → I don't know.
# ✅ idx 37 → Near the doorway in hallway.
# ✅ idx 38 → In the person's right hand.
# ✅ idx 40 → Seven cards held.
# ✅ idx 42 → On the table, near center.
# ✅ idx 44 → Light blue
# ✅ idx 45 → On the countertop.
# ✅ idx 46 → Next to the doorway floor.
# ✅ idx 47 → Beside you on chair.
# ✅ idx 48 → On your lap.
# ⚠️ No video stream in: /content/drive/MyDrive/model_2.0/model/cut_videos_6tol/49_b704e90e-d433-4b13-9f78-f2194c5f3f57_9da625ed-2321-4823-81c8-6679d6468d18.mp4
# ⚠️ Skipping idx 49
# ✅ idx 50 → Six
# ✅ idx 51 → One carrot grated.
# ⚠️ No video stream in: /content/drive/MyDrive/model_2.0/model/cut_videos_6tol/55_71e0d3e7-4706-4eb3-9a7a-85d01f46259f_0d80d25e-f3b1-44ec-8ca4-d19bb76a29c9.mp4
# ⚠️ Skipping idx 55
# ✅ idx 57 → Near your left foot.
# 💾 Checkpoint saved with 40 entries.
# ✅ idx 58 → On the workbench, near edge.
# ✅ idx 60 → Colored fabric
# ✅ idx 63 → In the refrigerator door.
# ✅ idx 64 → In the sink drain.
# ✅ idx 65 → Above the round table.
# ✅ idx 66 → Next to the tent.
# ✅ idx 68 → On the black table.
# ✅ idx 69 → Crumpled paper towel.
# ✅ idx 70 → In the bottom drawer.
# ✅ idx 71 → Three containers.
# ✅ idx 72 → One.
# ✅ idx 74 → Three scoops.
# ✅ idx 76 → Bread dough.
# ✅ idx 77 → On the metal table.
# ✅ idx 78 → Next to the brown bag.
# ✅ idx 79 → On bakery rack, top shelf.
# ✅ idx 81 → Beside the metal table.
# ✅ idx 82 → Left side of workspace.
# ✅ idx 84 → On the ground to left.
# ✅ idx 85 → In the fridge, middle shelf.
# 💾 Checkpoint saved with 60 entries.
# ✅ idx 87 → I don't know.
# ✅ idx 88 → On the grass, near skateboard.
# ⚠️ No video stream in: /content/drive/MyDrive/model_2.0/model/cut_videos_6tol/89_f562f1ab-0091-45a0-9e66-4de21d820675_73427cb5-30fd-4118-b01d-e3e15576c944.mp4
# ⚠️ Skipping idx 89
# ✅ idx 90 → Screwdriver
# ✅ idx 92 → I don't know.
# ✅ idx 93 → On the closet door.
# ✅ idx 95 → Pasta with sauce.
# ✅ idx 97 → Person using a laptop.
# ✅ idx 99 → On stacked bricks nearby.
# ✅ idx 100 → On the tractor seat.
# ✅ idx 101 → On the small chair.
# ✅ idx 103 → Green
# ⚠️ No video stream in: /content/drive/MyDrive/model_2.0/model/cut_videos_6tol/105_780f7a41-3573-4dd6-8658-d1c8c02ef0ba_19ba979b-ff30-4a79-afe5-b14139c85cc2.mp4
# ⚠️ Skipping idx 105
# ✅ idx 106 → Middle shelf, right side.
# ✅ idx 107 → White shopping bag.
# ✅ idx 109 → Next to the sink.
# ✅ idx 110 → On the workbench, top left.
# ✅ idx 113 → Yes.
# ✅ idx 116 → In hand, near door.
# ✅ idx 117 → In front of camera.
# ✅ idx 118 → One
# ✅ idx 120 → Near the building entrance.
# 💾 Checkpoint saved with 80 entries.
# ✅ idx 121 → Inside the glass-walled room.
# ✅ idx 122 → On the cutting board.
# ✅ idx 123 → On the counter to left.
# ✅ idx 125 → Blue
# ✅ idx 127 → Five bottles touched.
# ✅ idx 128 → Middle shelf in fridge.
# ✅ idx 129 → I don't know.
# ✅ idx 130 → From the stove area.
# ✅ idx 131 → Top shelf, center row.
# ⚠️ No video stream in: /content/drive/MyDrive/model_2.0/model/cut_videos_6tol/132_6d282ccf-931e-4ee3-a57e-f12447af2f2d_77686398-7e5a-47c2-a2f5-426d43177952.mp4
# ⚠️ Skipping idx 132
# ✅ idx 133 → Near the orange container, floor.
# ✅ idx 135 → Yes.
# ✅ idx 136 → Near the deck's center.
# ✅ idx 137 → Hanging on oven handle.
# ✅ idx 138 → White corner baseboard pieces.
# ✅ idx 139 → Near the fitting room area.
# ✅ idx 140 → In the garage, bottom center.
# ✅ idx 141 → Green rubber mallet.
# ✅ idx 142 → Black spatula with white handle.
# ✅ idx 143 → Oven handle.
# ✅ idx 145 → In the red container.
# 💾 Checkpoint saved with 100 entries.
# ✅ idx 146 → Eight clothes folded.
# ✅ idx 147 → On the couch cushion.
# ✅ idx 148 → On the wooden table.
# ✅ idx 149 → Energy drink from can.
# ✅ idx 150 → In person's hands, unfolded.
# ✅ idx 152 → On the yellow machine.
# ✅ idx 153 → One
# ✅ idx 154 → I don't know.
# ✅ idx 155 → Three screws taken out.
# ✅ idx 156 → Four
# ✅ idx 158 → Near blue bag, backseat.
# ✅ idx 160 → Green power drill.
# ✅ idx 162 → Coffee filter with grounds.
# ✅ idx 163 → On a metal table.
# ✅ idx 165 → On the table's right side.
# ⚠️ No video stream in: /content/drive/MyDrive/model_2.0/model/cut_videos_6tol/166_fc4bfef7-e079-4783-92e1-b768cfac8125_6f2fcdde-43ad-46f9-8778-40659a86218d.mp4
# ⚠️ Skipping idx 166
# ✅ idx 168 → No.
# ✅ idx 170 → Eight eggs visible.
# ✅ idx 171 → Eggs.
# ✅ idx 172 → On the left table.
# ✅ idx 173 → Sliced bread with butter.
# 💾 Checkpoint saved with 120 entries.
# ✅ idx 175 → Tape measure
# ✅ idx 176 → Toilet paper roll.
# ✅ idx 177 → Three slices.
# ✅ idx 178 → In the drawer.
# ✅ idx 179 → On the drying rack.
# ✅ idx 181 → Not visible in video.
# ✅ idx 182 → I don't know.
# ✅ idx 183 → Near stove, right-side counter.
# ✅ idx 185 → White with blue design.
# ⚠️ No video stream in: /content/drive/MyDrive/model_2.0/model/cut_videos_6tol/186_ed0a0e94-c79b-462d-a64b-238f26fd6fc6_312d4960-1288-4011-9896-05df5aee6c4c.mp4
# ⚠️ Skipping idx 186
# ✅ idx 187 → A vacuum cleaner plug.
# ✅ idx 190 → In the kitchen cabinet.
# ✅ idx 191 → On the red toolbox.
# ✅ idx 193 → On the ground, in dirt.
# ✅ idx 194 → Next to the ladder.
# ✅ idx 195 → On the wooden bench.
# ✅ idx 197 → In the white cabinet.
# ✅ idx 198 → Between table and feet.
# ✅ idx 199 → On the floor, coiled.
# ✅ idx 0 → Plastic bottle
# ✅ idx 1 → Bottom red drawer, storage unit.
# 💾 Checkpoint saved with 140 entries.
# ✅ idx 2 → Black
# ✅ idx 3 → On the cutting board.
# ✅ idx 4 → A knife.
# ✅ idx 5 → One bowl.
# ✅ idx 6 → Concrete mixing tool.
# ✅ idx 7 → On the trash can lid.
# ✅ idx 8 → Control panel on wall.
# ✅ idx 9 → Left of the faucet.
# ✅ idx 10 → Beside the building entrance.
# ✅ idx 11 → By the roadside near cliffs.
# ✅ idx 12 → On the metal counter.
# ✅ idx 13 → On the kitchen counter.
# ✅ idx 14 → Knife
# ✅ idx 15 → On the kitchen counter.
# ✅ idx 16 → Small rectangular wood block.
# ✅ idx 17 → Seven.
# ✅ idx 18 → On the concrete ledge.
# ✅ idx 19 → Two
# ✅ idx 20 → White board, red corners.
# ✅ idx 21 → In the open drawer.
# 💾 Checkpoint saved with 160 entries.
# ✅ idx 22 → Not visible in video.
# ✅ idx 23 → Next to the record player.
# ✅ idx 24 → No.
# ✅ idx 25 → Gray
# ✅ idx 26 → Eggs in a plastic container.
# ✅ idx 27 → A black cable tie.
# ✅ idx 28 → Near the front door entrance.
# ✅ idx 29 → Next to the sink.
# ✅ idx 30 → On top of washing machine.
# ✅ idx 31 → Yes.
# ✅ idx 32 → Three pieces of wood.
# ✅ idx 33 → By the garage door.
# ✅ idx 34 → On the floor, near feet.
# ✅ idx 35 → Four.
# ✅ idx 36 → On the green bedspread.
# ✅ idx 37 → On the patterned bedspread.
# ✅ idx 38 → Red
# ✅ idx 39 → Reddish-brown.
# ⚠️ No video stream in: /content/drive/MyDrive/model_2.0/model/cut_videos_6tol/40_f800514a-5fb0-4620-beb3-69d6c73ddb3f_b308eab3-64e5-451e-8c89-1713bd30b624.mp4
# ⚠️ Skipping idx 40
# ✅ idx 41 → In your hand.
# ✅ idx 42 → No.
# 💾 Checkpoint saved with 180 entries.
# ✅ idx 43 → Tent stake.
# ✅ idx 44 → Inside the refrigerator drawer.
# ✅ idx 45 → Two plates.
# ✅ idx 46 → A large piece of meat.
# ✅ idx 47 → Near the rocky hills.
# ✅ idx 48 → Flatbread dough.
# ✅ idx 49 → Five dough pieces.
# ✅ Final save completed. Total entries: 187
